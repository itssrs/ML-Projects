# %% [markdown]
# # New York Stock Exhange Predictions RNN-LSTM

# %%
import numpy as np # data processed in the form of array
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os #libray used to working in operating system files and processes
import matplotlib.pyplot as plt #data visulization library

# %% [markdown]
# # About it
#
# ## Dataset consists of following files:
#
# ### prices.csv:
# - raw, as-is daily prices. Most of data spans from 2010 to the end 2016, for companies new on stock market date range is shorter. There have been approx. 140 stock splits in that time, this set doesn't account for that.
# ### prices-split-adjusted.csv:
# - same as prices, but there have been added adjustments for splits.
# ### securities.csv:
# - general description of each company with division on sectors
# ### fundamentals.csv:
# - metrics extracted from annual SEC 10K fillings (2012-2016), should be enough to derive most of popular fundamental indicators.

# %%
#calling the file in nyse named prices.csv
df =pd.read_csv("prices.csv", header=0)
df.head()
# Out:
#                   date symbol        open       close         low        high  \
# 0  2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %% [markdown]
# ## Data Description
# **The table consists of data of New York Stock Exchange
# consist of 851264 entries**
#
# **Column1-- Date**
# - The date here are from 05-01-2016 to 30-12-2016 i.e of the year 2016 with many company performance**
#
# **Column2-- Symbols**
# - Symbols are code for 501 companies i.e each symbol is alloted to each corporation.**
#
# **Column3-- open**
# - open is the stock opening price of the date.**
#
# **Column4-- close**
# - close is the stock closing price of the date**
#
# **Column5-- low**
# - low is the lowest price of the date**
#
# **Column6-- high**
# - high is the highest price of the date.**

# %%
#size of the dataset in 851264 rows and 7 columns
print(df.shape)
# Out:
# (851264, 7)

# %%
# takes 20 different and unique from symbol
df.symbol.unique()[0:20]
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN'], dtype=object)

# %% [markdown]
# - symbols here are Ticker symbol from comp_info i.e they are the company code names

# %%
#gives the details of each columns of the dataset like mean, max etc
df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       70.836986      70.857109      70.118414      71.543476
# std        83.695876      83.689686      82.877294      84.465504
# min         0.850000       0.860000       0.830000       0.880000
# 25%        33.840000      33.849998      33.480000      34.189999
# 50%        52.770000      52.799999      52.230000      53.310001
# 75%        79.879997      79.889999      79.110001      80.610001
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
#checking whether their is any null value in the dataset
# .sum() will give the total no. of null value column vise 
df.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
# taking all the unique or one time value in the date column 
df.date.unique()
# Out:
# array(['2016-01-05 00:00:00', '2016-01-06 00:00:00',
#        '2016-01-07 00:00:00', ..., '2016-12-28', '2016-12-29',
#        '2016-12-30'], dtype=object)

# %%
#calling the file in nyse named securities.csv
comp_info = pd.read_csv('securities.csv')
comp_info.head()
# Out:
#   Ticker symbol             Security SEC filings             GICS Sector  \
# 0           MMM           3M Company     reports             Industrials
# 1           ABT  Abbott Laboratories     reports             Health Care
# 2          ABBV               AbbVie     reports             Health Care
# 3           ACN        Accenture plc     reports  Information Technology
# 4          ATVI  Activision Blizzard     reports  Information Technology
#
#                 GICS Sub Industry   Address of Headquarters Date first added  \
# 0        Industrial Conglomerates       St. Paul, Minnesota              NaN
# 1           Health Care Equipment   North Chicago, Illinois       31-03-1964
# 2                 Pharmaceuticals   North Chicago, Illinois       31-12-2012
# 3  IT Consulting & Other Services           Dublin, Ireland       06-07-2011
# 4     Home Entertainment Software  Santa Monica, California       31-08-2015
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# 3  1467373
# 4   718877

# %% [markdown]
# # Data description
# **Table consists of 504 entries of description of companies.**
#
# **column1-- Ticker Symbol**
# **It is the symbol of companies, same as symbol in df**
#
# **column2-- Security**
# **It is the name of the corporation like amazon.com Inc**
#
# **column4-- GICS Sector**
# **It is the type of the company. eg Adobe Systems Inc is Information Technology**
#
# **column5-- GICS Sub Industry**
# **It is the sub department of the type of company. eg Adobe Inc is Application Software**
#
# **column6-- Address of headquater**
# **It is company head base(main office) location**

# %%
# taking total no. of unique values in column Ticket symbol
comp_info["Ticker symbol"].nunique()
# Out:
# 505

# %%
# for locating specific data here.... in security column of string that starts with "Face"
comp_info.loc[comp_info.Security.str.startswith('Face') , :]
# Out:
#     Ticker symbol  Security SEC filings             GICS Sector  \
# 181            FB  Facebook     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 181  Internet Software & Services  Menlo Park, California       23-12-2013
#
#          CIK
# 181  1326801

# %% [markdown]
# **Selecting any 6 companies using above method for visualizations on respective opening and closing stock prices.**
# Yahoo Inc
# Xeror Corp
# Microsoft Corp
# Facebook
# Adobe Systems Inc
# Goldman Sachs Group

# %%
# here we locate Ticker symbol of company with security like Yahoo, Xerox, Adobe etc 
# then taking their no. of times entry and thier "Ticker symbol"
comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc') 
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') , ["Ticker symbol"] ]["Ticker symbol"] 
print(comp_plot)
# Out:
# 6      ADBE
# 181      FB
# 212      GS
# 306    MSFT
# 496     XRX
# 500    YHOO
# Name: Ticker symbol, dtype: object

# %% [markdown]
# **Some companies and their opening and closing stock prices.**
# **Note: The differences is marginal , you might take open and close same but they are actually different after looking carefully.**

# %% [markdown]
# # Purpose of def function plotter:
#
# **Here the purpose arose to see the progress or loss of the Companies**
#
# **we needed a visual graph of the stock excancge price vs time**
#
# **We needed to compare close prices and open price of each date**
#
# **so we define a function that will display all 6 company open and close graph in total 12 graphs**

# %%
def plotter(code):
    # creating variable for whole notebook
    global closing_stock ,opening_stock
    #creating plot of all 6 company for opening and closing
    f, axs = plt.subplots(2,2,figsize=(8,8))
    # total 12 graphs
    # creating plot opening prize of particular company
    plt.subplot(212)
    #taking name of the company as code
    company = df[df['symbol']==code]
    #taking the values of one company and taking its open column values
    company = company.open.values.astype('float32')
    #reshaping the open column value in 1D and calling it opening_stock
    company = company.reshape(-1, 1)
    # putting the value of company in opening_stock 
    opening_stock = company
    # plotting the data with green graph between "Time" and "prices vs time"
    
    plt.grid(True)# enalbling the grid in graph
    plt.xlabel('Time') # setting X axis as time
    plt.ylabel(code + " open stock prices") # setting Y axis as company name + open stock prices
    plt.title('prices Vs Time') # setting title
    plt.plot(company , 'g') # calling the graph with green graph line
    
    # creating plot closing prize of particular company
    plt.subplot(211)
    #taking name of the company as code
    company_close = df[df['symbol']==code]
    #taking the values of one company and taking its close column values
    company_close = company_close.close.values.astype('float32')
    #reshaping the open column value in 1D and calling it closing_stock
    company_close = company_close.reshape(-1, 1)
    # putting company_close value in closing_stock 
    closing_stock = company_close
    # plotting the data graph between "Time" and "prices vs time"
    
    plt.xlabel('Time') # setting x axis as time
    plt.ylabel(code + " close stock prices")# setting y axis as company name + open stock prices
    plt.title('prices Vs Time') # setting title as price vs time
    plt.grid(True) # enabling the grid in graph
    plt.plot(company_close , 'b') #creating the data graph in blue graph line
    plt.show() # calling the graph

# calling the graphs through the function    
for i in comp_plot:
    plotter(i)

# %% [markdown]
# **Lets take a single stock as a sample to forecast further stock prices.**

# %% [markdown]
# # plot summary
#
# ## Adobe report
# **As we can see, That close and open started around 38 points and shows a increasing growth with the time. The open and close graph closes at a very high position (around 105) compared to the start.**
#
# ## Facebook report
# **As the graph shows, open and close started around 30 points. And from their it show a bit downfall time 150. But then it shows massive up rise and ends at the120 points for both open and close.**
#
# ## Goldman Sachs
# **As we see in graphs of open and close stocks, we see that Goldman has taking many up and downs almost the whole journey. It startest from high points than others around 175 points and faced major down fall but at last it reached higher to 240 points.**
# ## Microsoft
# **As the graphs explain open and close stock for Microsoft strated from 30 points. And from there they show total elevation to 65 points. Its a great option for investment**
# ## Xerox
# **As the graphs suggest for Xerox, It started from very low points of 9 and from there it struggled to progess. There was a major fall after some time and at the end the stock prices are still nearly same.**
# ## Yahoo
# **As we see the graphs, Yahoo prices remained same for some time. But then they show effective progress.
# And at the  end they go to around 40 points.**

# %%
#taking the values of closing_stock in a single list called stocks
stocks = closing_stock[: , 0]
print(stocks)
#reshaping the stocks in 1D array form
stocks = stocks.reshape(len(stocks) , 1)
# Out:
# [17.1  17.23 17.17 ... 38.73 38.64 38.67]

# %% [markdown]
# **Feature scaling the vector for better model performance.**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) #scaling features between 0 and 1
stocks = scaler.fit_transform(stocks) # it will start learning algo and then provide scaled and dimension reduced output

# %% [markdown]
# ## minmaxscaler
# - Transform features by scaling each feature to a given range.This estimator scales and translates each feature individually such that it is in the given range on the training set, e.g. between zero and one.This transformation is often used as an alternative to zero mean, unit variance scaling.

# %%
train = int(len(stocks) * 0.80) #creating sizes of train and taking 80% percentage of the part
test = len(stocks) - train #creating sizes of test as total minus train

# %%
#sizes of train and test
print(train , test)
# Out:
# 1409 353

# %%
#divinding the values of stocks data to train from 0 to 1409 i.e 80% data
train = stocks[0:train]
print(train)
# Out:
# [[0.14559111]
#  [0.14874032]
#  [0.14728683]
#  ...
#  [0.63372093]
#  [0.6145833 ]
#  [0.6196705 ]]

# %%
#divinding the values of stocks data to test from train ending to stock data ending i.e rest 20% data
test = stocks[len(train) : ]

# %%
#reshaping train data in 1D array form
train = train.reshape(len(train) , 1)
#reshaping test data in 1D array form
test = test.reshape(len(test) , 1)

# %%
#new train and test array shape
print(train.shape , test.shape)
# Out:
# (1409, 1) (353, 1)

# %% [markdown]
# **process_data for the required input for LSTM.**

# %%
#creating function to create trainX,testX and target(trainY, testY)
def process_data(data , n_features):
    dataX, dataY = [], [] # creating data for dataset and dividing inta X,Y
    for i in range(len(data)-n_features-1):
        # taking i range from total size- 3 
        a = data[i:(i+n_features), 0]
        # her a is value of data from i to i+ n_features in 1D and putting it in dataX 
        dataX.append(a) #putting a in dataX
        #here dataY takes the value of data of i + n_features
        dataY.append(data[i + n_features, 0])
        # putting i+ n_features in  dataY
    return np.array(dataX), np.array(dataY)
# returning dataX and dataY in array

#so the stucture of trainX and trainY is somehow like this
# trainX=[[i1 , i2,...., i n_features ]] and trainY=[i + n_features]  
# trainY will show the future value of trainX values

# %% [markdown]
# **Here I am taking 2 past values to predict a single value. This has already been checked and optimized after taking several cases.**
# **TrainY is set in such a way that it will show the ahead value or future time value of the given data(trainX)
# So when we train the data it will learn to predict the future value of further ahead.**

# %%
n_features = 2
# and here we create train X,Y and test X,Y data where trainX, testX has two value is each block
trainX, trainY = process_data(train, n_features)
# testY, trainY has one value that will be of two step ahead of corresponding(testY,trainX) value
testX, testY = process_data(test, n_features)

# %%
# printing the structure of train X,Y and test X,Y
print(trainX.shape , trainY.shape , testX.shape , testY.shape)
# Out:
# (1406, 2) (1406,) (350, 2) (350,)

# %% [markdown]
# **Reshaping again for required LSTM input as (sample , timestamp , features per sample).**

# %% [markdown]
# **Here I am taking timestamp as 1.**

# %%
# reshaping trainX and testX to use in deeplearning model
trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])

# %%
import math # helps us do mathematical operations
from keras.models import Sequential # for setting layers one by one neural layer in model 
from keras.layers import Dense , BatchNormalization , Dropout , Activation # types of layers
from keras.layers import LSTM , GRU # types of RNN
from sklearn.preprocessing import MinMaxScaler #It puts the data in between given range to set data before putting layer
from sklearn.metrics import mean_squared_error # In this method the errors in column is squared and then mean is found 
from keras.optimizers import Adam , SGD , RMSprop # they are the algos that found the output for model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Checkpointing the model when required and using other callbacks.**

# %%
filepath="stock_weights1.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
# the model reduce the learning rate where the value are not repeated or too close to reduce overfitting
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
# for saving the best result value from the epoochs as checkpoints
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')
# Out:
# C:\Users\shash\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------

# %%
# creating model for training data using sequential to give series wise output between layers
model = Sequential()
# GRU or Gated Recurrent Unit used for matrix manipulation within Recurrent layer
model.add(GRU(256 , input_shape = (1 , n_features) , return_sequences=True))
#dropout is used to remove overfitting data on each layer of neural network
model.add(Dropout(0.4))
#Long Short Term Memory is a type of RNN specially used for time series problems
model.add(LSTM(256))
#dropout is used to remove overfitting data on each layer of neural network
model.add(Dropout(0.4))
#Dense layer are fully connected neural networks 
model.add(Dense(64 ,  activation = 'relu'))
model.add(Dense(1))
#for getting the details of our models
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 1, 256)            198912
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 740,737
# Trainable params: 740,737
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# selecting the loss measurement metrics and optimizer for our model , to find out mean square error
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])

# %%
# fitting the data i.e training the trainX, to relate to trainY
# epochs is the times each data in send to fit
# batch size is the size of information send at a time
# validation_data is the validation or data used for testing 
history = model.fit(trainX, trainY, epochs=100 , batch_size = 128 , 
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))    
#callbacks are proper
# Out:
# Train on 1406 samples, validate on 350 samples
# Epoch 1/100
# 1406/1406 [==============================] - 3s 2ms/step - loss: 0.1563 - mean_squared_error: 0.1563 - val_loss: 0.2113 - val_mean_squared_error: 0.2113
#
# Epoch 00001: val_loss improved from -inf to 0.21128, saving model to stock_weights1.hdf5
# Epoch 2/100
# 1406/1406 [==============================] - 1s 399us/step - loss: 0.0590 - mean_squared_error: 0.0590 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
#
# Epoch 00002: val_loss did not improve from 0.21128
# Epoch 3/100
# 1406/1406 [==============================] - 1s 370us/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
#
# Epoch 00003: val_loss did not improve from 0.21128
# Epoch 4/100
# 1406/1406 [==============================] - 0s 349us/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
#
# Epoch 00004: val_loss did not improve from 0.21128
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 5/100
# 1406/1406 [==============================] - 1s 366us/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
#
# Epoch 00005: val_loss did not improve from 0.21128
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# Epoch 6/100
# 1406/1406 [==============================] - 1s 375us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00006: val_loss did not improve from 0.21128
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# Epoch 7/100
# 1406/1406 [==============================] - 1s 384us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00007: val_loss did not improve from 0.21128
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# Epoch 8/100
# 1406/1406 [==============================] - 0s 354us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00008: val_loss did not improve from 0.21128
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# Epoch 9/100
# 1406/1406 [==============================] - 0s 337us/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00009: val_loss did not improve from 0.21128
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# Epoch 10/100
# 1406/1406 [==============================] - 1s 367us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00010: val_loss did not improve from 0.21128
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# Epoch 11/100
# 1406/1406 [==============================] - 1s 367us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00011: val_loss did not improve from 0.21128
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# Epoch 12/100
# 1406/1406 [==============================] - 0s 341us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00012: val_loss did not improve from 0.21128
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# Epoch 13/100
# 1406/1406 [==============================] - 1s 378us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00013: val_loss did not improve from 0.21128
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# Epoch 14/100
# 1406/1406 [==============================] - 1s 364us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00014: val_loss did not improve from 0.21128
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# Epoch 15/100
# 1406/1406 [==============================] - 1s 366us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00015: val_loss did not improve from 0.21128
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# Epoch 16/100
# 1406/1406 [==============================] - 0s 343us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00016: val_loss did not improve from 0.21128
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# Epoch 17/100
# 1406/1406 [==============================] - 1s 376us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00017: val_loss did not improve from 0.21128
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# Epoch 18/100
# 1406/1406 [==============================] - 1s 365us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00018: val_loss did not improve from 0.21128
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# Epoch 19/100
# 1406/1406 [==============================] - 0s 352us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00019: val_loss did not improve from 0.21128
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# Epoch 20/100
# 1406/1406 [==============================] - 1s 358us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00020: val_loss did not improve from 0.21128
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# Epoch 21/100
# 1406/1406 [==============================] - 0s 341us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00021: val_loss did not improve from 0.21128
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# Epoch 22/100
# 1406/1406 [==============================] - 0s 349us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00022: val_loss did not improve from 0.21128
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# Epoch 23/100
# 1406/1406 [==============================] - 0s 354us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00023: val_loss did not improve from 0.21128
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# Epoch 24/100
# 1406/1406 [==============================] - 0s 352us/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00024: val_loss did not improve from 0.21128
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# Epoch 25/100
# 1406/1406 [==============================] - 1s 375us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00025: val_loss did not improve from 0.21128
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# Epoch 26/100
# 1406/1406 [==============================] - 1s 361us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00026: val_loss did not improve from 0.21128
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# Epoch 27/100
# 1406/1406 [==============================] - 1s 362us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00027: val_loss did not improve from 0.21128
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# Epoch 28/100
# 1406/1406 [==============================] - 1s 356us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00028: val_loss did not improve from 0.21128
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# Epoch 29/100
# 1406/1406 [==============================] - 1s 371us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00029: val_loss did not improve from 0.21128
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# Epoch 30/100
# 1406/1406 [==============================] - 0s 352us/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00030: val_loss did not improve from 0.21128
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# Epoch 31/100
# 1406/1406 [==============================] - 1s 363us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00031: val_loss did not improve from 0.21128
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# Epoch 32/100
# 1406/1406 [==============================] - 0s 352us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00032: val_loss did not improve from 0.21128
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# Epoch 33/100
# 1406/1406 [==============================] - 1s 371us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00033: val_loss did not improve from 0.21128
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# Epoch 34/100
# 1406/1406 [==============================] - 1s 390us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00034: val_loss did not improve from 0.21128
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# Epoch 35/100
# 1406/1406 [==============================] - 1s 358us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00035: val_loss did not improve from 0.21128
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# Epoch 36/100
# 1406/1406 [==============================] - 1s 389us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00036: val_loss did not improve from 0.21128
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# Epoch 37/100
# 1406/1406 [==============================] - 1s 356us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00037: val_loss did not improve from 0.21128
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# Epoch 38/100
# 1406/1406 [==============================] - 1s 365us/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00038: val_loss did not improve from 0.21128
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# Epoch 39/100
# 1406/1406 [==============================] - 0s 343us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00039: val_loss did not improve from 0.21128
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# Epoch 40/100
# 1406/1406 [==============================] - 0s 344us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00040: val_loss did not improve from 0.21128
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# Epoch 41/100
# 1406/1406 [==============================] - 0s 355us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00041: val_loss did not improve from 0.21128
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# Epoch 42/100
# 1406/1406 [==============================] - 0s 354us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00042: val_loss did not improve from 0.21128
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# Epoch 43/100
# 1406/1406 [==============================] - 1s 364us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00043: val_loss did not improve from 0.21128
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# Epoch 44/100
# 1406/1406 [==============================] - 0s 349us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00044: val_loss did not improve from 0.21128
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# Epoch 45/100
# 1406/1406 [==============================] - 1s 356us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00045: val_loss did not improve from 0.21128
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# Epoch 46/100
# 1406/1406 [==============================] - 0s 346us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00046: val_loss did not improve from 0.21128
# Epoch 47/100
# 1406/1406 [==============================] - 0s 351us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00047: val_loss did not improve from 0.21128
# Epoch 48/100
# 1406/1406 [==============================] - 1s 357us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00048: val_loss did not improve from 0.21128
# Epoch 49/100
# 1406/1406 [==============================] - 0s 340us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00049: val_loss did not improve from 0.21128
# Epoch 50/100
# 1406/1406 [==============================] - 1s 370us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00050: val_loss did not improve from 0.21128
# Epoch 51/100
# 1406/1406 [==============================] - 0s 333us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00051: val_loss did not improve from 0.21128
# Epoch 52/100
# 1406/1406 [==============================] - 0s 352us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00052: val_loss did not improve from 0.21128
# Epoch 53/100
# 1406/1406 [==============================] - 1s 360us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00053: val_loss did not improve from 0.21128
# Epoch 54/100
# 1406/1406 [==============================] - 0s 353us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00054: val_loss did not improve from 0.21128
# Epoch 55/100
# 1406/1406 [==============================] - 1s 371us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00055: val_loss did not improve from 0.21128
# Epoch 56/100
# 1406/1406 [==============================] - 0s 347us/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00056: val_loss did not improve from 0.21128
# Epoch 57/100
# 1406/1406 [==============================] - 1s 362us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00057: val_loss did not improve from 0.21128
# Epoch 58/100
# 1406/1406 [==============================] - 0s 342us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00058: val_loss did not improve from 0.21128
# Epoch 59/100
# 1406/1406 [==============================] - 1s 356us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00059: val_loss did not improve from 0.21128
# Epoch 60/100
# 1406/1406 [==============================] - 1s 373us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00060: val_loss did not improve from 0.21128
# Epoch 61/100
# 1406/1406 [==============================] - 0s 336us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00061: val_loss did not improve from 0.21128
# Epoch 62/100
# 1406/1406 [==============================] - 1s 375us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00062: val_loss did not improve from 0.21128
# Epoch 63/100
# 1406/1406 [==============================] - 0s 355us/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00063: val_loss did not improve from 0.21128
# Epoch 64/100
# 1406/1406 [==============================] - 1s 361us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00064: val_loss did not improve from 0.21128
# Epoch 65/100
# 1406/1406 [==============================] - 0s 340us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00065: val_loss did not improve from 0.21128
# Epoch 66/100
# 1406/1406 [==============================] - 1s 366us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00066: val_loss did not improve from 0.21128
# Epoch 67/100
# 1406/1406 [==============================] - 1s 368us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00067: val_loss did not improve from 0.21128
# Epoch 68/100
# 1406/1406 [==============================] - 1s 372us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00068: val_loss did not improve from 0.21128
# Epoch 69/100
# 1406/1406 [==============================] - 1s 356us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00069: val_loss did not improve from 0.21128
# Epoch 70/100
# 1406/1406 [==============================] - 1s 366us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00070: val_loss did not improve from 0.21128
# Epoch 71/100
# 1406/1406 [==============================] - 1s 403us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00071: val_loss did not improve from 0.21128
# Epoch 72/100
# 1406/1406 [==============================] - 1s 356us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00072: val_loss did not improve from 0.21128
# Epoch 73/100
# 1406/1406 [==============================] - 1s 360us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00073: val_loss did not improve from 0.21128
# Epoch 74/100
# 1406/1406 [==============================] - 1s 359us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00074: val_loss did not improve from 0.21128
# Epoch 75/100
# 1406/1406 [==============================] - 1s 366us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00075: val_loss did not improve from 0.21128
# Epoch 76/100
# 1406/1406 [==============================] - 1s 357us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00076: val_loss did not improve from 0.21128
# Epoch 77/100
# 1406/1406 [==============================] - 1s 366us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00077: val_loss did not improve from 0.21128
# Epoch 78/100
# 1406/1406 [==============================] - 1s 362us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00078: val_loss did not improve from 0.21128
# Epoch 79/100
# 1406/1406 [==============================] - 1s 388us/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00079: val_loss did not improve from 0.21128
# Epoch 80/100
# 1406/1406 [==============================] - 1s 369us/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00080: val_loss did not improve from 0.21128
# Epoch 81/100
# 1406/1406 [==============================] - 0s 355us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00081: val_loss did not improve from 0.21128
# Epoch 82/100
# 1406/1406 [==============================] - 1s 371us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00082: val_loss did not improve from 0.21128
# Epoch 83/100
# 1406/1406 [==============================] - 1s 375us/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00083: val_loss did not improve from 0.21128
# Epoch 84/100
# 1406/1406 [==============================] - 0s 354us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00084: val_loss did not improve from 0.21128
# Epoch 85/100
# 1406/1406 [==============================] - 1s 369us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00085: val_loss did not improve from 0.21128
# Epoch 86/100
# 1406/1406 [==============================] - 0s 347us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00086: val_loss did not improve from 0.21128
# Epoch 87/100
# 1406/1406 [==============================] - 0s 348us/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00087: val_loss did not improve from 0.21128
# Epoch 88/100
# 1406/1406 [==============================] - 0s 351us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00088: val_loss did not improve from 0.21128
# Epoch 89/100
# 1406/1406 [==============================] - 0s 353us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00089: val_loss did not improve from 0.21128
# Epoch 90/100
# 1406/1406 [==============================] - 1s 361us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00090: val_loss did not improve from 0.21128
# Epoch 91/100
# 1406/1406 [==============================] - 0s 349us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00091: val_loss did not improve from 0.21128
# Epoch 92/100
# 1406/1406 [==============================] - 0s 348us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00092: val_loss did not improve from 0.21128
# Epoch 93/100
# 1406/1406 [==============================] - 0s 345us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00093: val_loss did not improve from 0.21128
# Epoch 94/100
# 1406/1406 [==============================] - 0s 356us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00094: val_loss did not improve from 0.21128
# Epoch 95/100
# 1406/1406 [==============================] - 1s 356us/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00095: val_loss did not improve from 0.21128
# Epoch 96/100
# 1406/1406 [==============================] - 0s 350us/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00096: val_loss did not improve from 0.21128
# Epoch 97/100
# 1406/1406 [==============================] - 0s 351us/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00097: val_loss did not improve from 0.21128
# Epoch 98/100
# 1406/1406 [==============================] - 0s 342us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00098: val_loss did not improve from 0.21128
# Epoch 99/100
# 1406/1406 [==============================] - 1s 380us/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00099: val_loss did not improve from 0.21128
# Epoch 100/100
# 1406/1406 [==============================] - 0s 335us/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
#
# Epoch 00100: val_loss did not improve from 0.21128

# %%
import matplotlib.pyplot as plt
# here comparing the loss with mean squared error
# it call the graph with labels, titlea, lines
plt.plot(history.history['mean_squared_error']) #from fitting 
plt.plot(history.history['val_mean_squared_error'])# val_mean_squared_error is property from callbacks
plt.title('model mean squared error') # setting the title of the graph
plt.ylabel('loss') # label of X axis
plt.xlabel('epoch')# label of y axis
plt.legend(['train', 'test'], loc='upper left') # key of the graph to tell difference between train and test graph
plt.show() # it call the graph with labels, titlea, lines
# summarize history for loss
# plt.plot is used to built the gra
plt.plot(history.history['loss']) # loss is the value of cost function for your traing data
plt.plot(history.history['val_loss'])# val_loss is the value of cost function for your cross-validation data 
plt.title('model loss')#  setting the title of the graph
plt.ylabel('loss') # label of X axis
plt.xlabel('epoch') # label of Y axis
plt.legend(['train', 'test'], loc='upper left')  # key of the graph to tell difference between train and test graph
plt.show() # it call the graph with labels, titles, lines

# %%
def model_score(model, X_train, y_train, X_test, y_test):
    # model. evaluate gives us the overall accuracy and loss
    trainScore = model.evaluate(X_train, y_train, verbose=0)
    #here for trainX and trainY we print mean square error and root mean square error
    print('Train Score: %.5f MSE (%.2f RMSE)' % (trainScore[0], math.sqrt(trainScore[0])))
    # model. evaluate gives us the overall accuracy and loss
    testScore = model.evaluate(X_test, y_test, verbose=0)
    #here for testX and testY we print mean square error and root mean square error
    print('Test Score: %.5f MSE (%.2f RMSE)' % (testScore[0], math.sqrt(testScore[0])))
    # returns the loss of train and test 
    return trainScore[0], testScore[0]

# will return the value of overall mean squared error
model_score(model, trainX, trainY , testX, testY)
# Out:
# Train Score: 0.00650 MSE (0.08 RMSE)
# Test Score: 0.00737 MSE (0.09 RMSE)
# (0.006501688788198517, 0.007366646091852869)

# %% [markdown]
# # def function model_score:
# We required a function that will give loss (mean square error) of train and test value as return
#
# Conclusion here is mean square error of test(0.00652) and train(0.00485)
# **Inverse transforming the scaled vector earlier and checking for the error visually in the graph.**

# %% [markdown]
# # Mean Squared Error
#
#  Mean Squared Deviation (MSD) of an estimator measures the average of error squares i.e. the average squared difference between the estimated values and true value. It is a risk function, corresponding to the expected value of the squared error loss. It is always non – negative and values close to zero are better.

# %%
#predicting the value for testX
pred = model.predict(testX)
#converting pred list in 1D array so that it will be efficient in ploting
pred = scaler.inverse_transform(pred)
# prediction here will be the stock market price of further ahead of given company details
pred[:10]
# taking pred from 1 to 10
# Out:
# array([[33.237347],
#        [32.272053],
#        [32.160736],
#        [32.830467],
#        [32.90416 ],
#        [32.709087],
#        [32.377815],
#        [31.811113],
#        [30.989454],
#        [29.988508]], dtype=float32)

# %%
# reshaping testY in single array
testY = testY.reshape(testY.shape[0] , 1)
#converting reshaped list in 1D array so that it will be efficient in ploting
testY = scaler.inverse_transform(testY)
# taking testY from 1 to 10
testY[:10]
# Out:
# array([[34.49    ],
#        [35.93    ],
#        [36.24    ],
#        [36.1     ],
#        [35.69    ],
#        [35.19    ],
#        [34.1     ],
#        [32.93    ],
#        [31.31    ],
#        [31.739998]], dtype=float32)

# %% [markdown]
# ## The space between the predicted (red) and actual (blue) line is self explanatory for the model tuning and performance.

# %%
# ploting the graph of stock prices with time
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
# testY is the blue line grap
plt.plot(testY , 'b')
# pred is the red line grap
plt.plot(pred , 'r')
# setting x asix as time
plt.xlabel('Time')
# setting y asux as stock prices
plt.ylabel('Stock Prices')
# setting title 
plt.title('Check the accuracy of the model with time')
# enabling grids in graph 
plt.grid(True)
# it call the graph with labels, titles, lines
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %% [markdown]
# # Conclusion
#
# ### As the last graph predicts the stock exchange Prices with further ahead Time.
# ### The blue(actual) and Red(predicted) are having a minute difference. It's very efficient.
# ### The overall error here is calculated with Mean Square Error and it error value is 0.00707 for test data.
# ### Since the error is so small .Thus the model is working very properly and is usable.
# **At many place the predicted value and actual value collide in the graph
# example price btw 30-35 on time 0-50**
